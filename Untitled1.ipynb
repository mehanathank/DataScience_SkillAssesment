# %% [markdown]
# <a href="https://colab.research.google.com/github/mehanathank/DataScience_SkillAssesment/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-72a626cd-8088-475e-b6c6-e82fb62e191b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-72a626cd-8088-475e-b6c6-e82fb62e191b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Q49_digital_payments.csv")

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
df.head()
# Out:
#   business_id business_type  transaction_count  transaction_value_inr  \
# 0      DP0001        Retail              681.0              445147.86
# 1      DP0002      Services             1134.0              525966.83
# 2      DP0003        Retail             1468.0              148239.26
# 3      DP0004    Restaurant             1427.0              585659.17
# 4      DP0005      Services             1231.0              111640.85
#
#    operating_hours_per_day  digital_payment_usage_percent
# 0                     13.1                           85.8
# 1                     15.0                           68.6
# 2                     12.8                           87.6
# 3                     11.4                           89.4
# 4                      5.6                           76.6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   business_id                    123 non-null    object
#  1   business_type                  123 non-null    object
#  2   transaction_count              122 non-null    float64
#  3   transaction_value_inr          123 non-null    float64
#  4   operating_hours_per_day        122 non-null    float64
#  5   digital_payment_usage_percent  122 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 5.9+ KB

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 123
# Columns: 6

# %%
df.isnull().sum()
# Out:
# business_id                      0
# business_type                    0
# transaction_count                1
# transaction_value_inr            0
# operating_hours_per_day          1
# digital_payment_usage_percent    1
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(3)

# %%
df["transaction_count"].fillna(df["transaction_count"].median(), inplace=True)
df["operating_hours_per_day"].fillna(df["operating_hours_per_day"].median(), inplace=True)
df["digital_payment_usage_percent"].fillna(df["digital_payment_usage_percent"].median(), inplace=True)
# Out:
# /tmp/ipykernel_561/3525422020.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["transaction_count"].fillna(df["transaction_count"].median(), inplace=True)
# /tmp/ipykernel_561/3525422020.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isnull().sum()
# Out:
# business_id                      0
# business_type                    0
# transaction_count                0
# transaction_value_inr            0
# operating_hours_per_day          0
# digital_payment_usage_percent    0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["business_type"].value_counts()
# Out:
# business_type
# Services        28
# Wholesale       28
# Retail          23
# HomeBusiness    21
# Restaurant      20
# Name: count, dtype: int64

# %% [markdown]
# point 2

# %%
df.groupby("business_type")["digital_payment_usage_percent"].mean()
# Out:
# business_type
# HomeBusiness    69.709524
# Restaurant      83.890000
# Retail          79.291304
# Services        70.385714
# Wholesale       73.371429
# Name: digital_payment_usage_percent, dtype: float64

# %%
df["transaction_value_range"] = pd.cut(
    df["transaction_value_inr"],
    bins=[0, 1000, 5000, 10000, float("inf")],
    labels=["Low", "Medium", "High", "Very High"]
)

# %%
df.groupby("transaction_value_range", observed=False)["digital_payment_usage_percent"].mean()
# Out:
# transaction_value_range
# Low                NaN
# Medium             NaN
# High         71.000000
# Very High    74.954622
# Name: digital_payment_usage_percent, dtype: float64

# %% [markdown]
# point 3

# %%
adoption_rate = df["digital_payment_usage_percent"].mean()

print("Digital Payment Adoption Rate:", adoption_rate, "%")
# Out:
# Digital Payment Adoption Rate: 74.92166666666665 %

# %%
df["transaction_volume_group"] = pd.cut(
    df["transaction_count"],
    bins=[0, 100, 300, float("inf")],
    labels=["Low", "Medium", "High"]
)

# %%
df["transaction_volume_group"].value_counts()
# Out:
# transaction_volume_group
# High      105
# Medium     11
# Low         4
# Name: count, dtype: int64
